# %%
import pandas as pd

import matplotlib.pyplot as plt
import japanize_matplotlib

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
"""
[
  { "time": 1730284561.08, "x": -0.5721972584724426, "y": 1.06965970993042, "z": 0.009765835478901863 },
]
"""
distances = pd.read_json('./data/distances.json')
print(distances)
"""
[
  {
    "time": 1730284561.08,
    "x": -0.2936166746829462,
    "y": -0.6450802569668366,
    "z": -0.35469098375794833,
    "w": 0.6097991945726983
  },
]
"""
quaternion = pd.read_json('./data/quaternion.json')
# Out:
#                  t         x         y         z
# 0     1.730292e+09  0.000000  0.000000  5.000000
# 1     1.730292e+09  0.000000  0.000000  5.000000
# 2     1.730292e+09  0.000000  0.000000  5.000000
# 3     1.730292e+09  0.000000  0.000000  5.000000
# 4     1.730292e+09  0.000000  0.000000  5.000000
# ...            ...       ...       ...       ...
# 1677  1.730292e+09 -0.489385  2.183515  0.221153
# 1678  1.730292e+09 -0.495320  2.196608  0.225744
# 1679  1.730292e+09 -0.498469  2.202870  0.228354
# 1680  1.730292e+09 -0.501673  2.209243  0.231192
# 1681  1.730292e+09 -0.508302  2.222171  0.237105
#
# [1682 rows x 4 columns]

# %%
# 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(distances['x'], distances['y'], distances['z'], '.-', zorder=1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_xlim(distances['x'].min(), distances['x'].max())
ax.set_ylim(distances['y'].min(), distances['y'].max())
ax.set_zlim(distances['z'].min(), distances['z'].max())
plt.show()
